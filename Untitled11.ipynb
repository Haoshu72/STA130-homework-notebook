# %% [markdown]
# Q1. The "first pre-lecture video" (above) describes hypothesis testing as addressing "an idea that can be tested", and the end of the video then discusses what our actual intended purpose in setting up a null hypothesis is. What is the key factor that makes the difference between ideas that can, and cannot be examined and tested statistically? What would you describe is the key "criteria" defining what a good null hypothesis is? And what is the difference between a null hypothesis and an alternative hypothesis in the context of hypothesis testing? Answer these questions with concise explanations in your own words.
# (1)The key to statistically-testable ideas is to be measurable and supported by data. If the idea can not be supported by measurable data, mostly people's subjective ideas, it can not be tested statistically.
# (2)A good null hypothesis must be explicit, concrete, and testable. It should state a position and have plenty of data to back it up.
# (3)The null hypothesis (H₀) indicates that the hypothesis assume nothing happen, on the other hand, the alternative hypothesis (H₁) indicates that there assume something happen. The two are opposed and can only support one or the other. The purpose of hypothesis testing is to determine whether there is enough data to reject the null hypothesis in favor of the alternative hypothesis.

# %% [markdown]
# Q2.
# (1)A data point is a single data point or value in a randomly drawn sample. For example, if you measure a student's height, each height is a data point.
# (2)Sample mean, which is the average calculated by taking several sample data points in a row. In the height example, the sample mean is the average height of the students you measure.
# (3)𝜇 is a fixed value that represents the true average for the entire population.
# (4)μ0 is the value that we assume the population mean should equal.

# %% [markdown]
# Q3. The second "Pre-lecture" video (above) explains that we "imagine a world where the null hypothesis is true" when calculating a p-value? Explain why this is in your own words in a way that makes the most sense to you.
#
# H0 and Ha are opposite, we put what we want to prove in Ha. But since proving Ha requires ensuring that it is correct in many cases, which is difficult, we now default that H0 is true, if we cannot prove H0 is true, we can conclude that Ha is true, and vice versa. Therefore, we should assume that the null hypothesis is correct to calculate the p-value. For example, in the video, we assume that the H0 puppy is innocent, which is correct, but we find that the P-value is very small in this case, which can overturn the null hypothesis, which is wrong, and draw the correct conclusion.

# %% [markdown]
# Q4. The second "Pre-lecture" video (above) suggests that a smaller p-value makes the null hypothesis look more ridiculous. Explain why this is in your own words in a way that makes the most sense to you, clarifying the meaning of any technical statistical terminology you use in your answer.
#
# When calculating the p-value, we assume that the null hypothesis is true, which helps us understand how likely the data we collect is if the null hypothesis holds. If the p-value is very small, it indicates that the observed data is unusual in the case that the null hypothesis holds, thus providing stronger evidence against the null hypothesis. Therefore, we may reject the null hypothesis and conclude. On the other hand, a large P-value indicates that the observed data is consistent with what we would expect if the null hypothesis were true, which means that the null hypothesis is true. For example, in the video about the dog, if the null hypothesis is that the dog is innocent, then by default, the garbage cover on its head can only be done by others, but in fact, it is extremely unlikely that the neighbor enters the house to put the garbage cover on the dog, and the P-value is very small. However, the litter cap did appear on the dog's neck, so the null hypothesis is wrong, and the dog put the litter cap on itself.

# %% [markdown]
# Q5.
# Hypothesis: The null hypothesis (H0) states that there is no inherent preference for head tilting direction when kissing. This hypothesis suggests that people are equally likely to tilt their heads to the left or the right, similar to a 50/50 chance in flipping a coin.

# %%
import numpy as np

trials = 10000  
sample_size = 124 
observed_rights = 80 
np.random.seed(42) 

original_data = np.array([1] * int(sample_size / 2) + [0] * int(sample_size / 2))

bootstrap_counts = np.zeros(trials)
for i in range(trials):

    bootstrap_sample = np.random.choice(original_data, size=sample_size, replace=True)
    bootstrap_counts[i] = np.sum(bootstrap_sample)  

p_value = np.mean(bootstrap_counts >= observed_rights)

print("P-value:", p_value)
# Out:
# P-value: 0.0005

# %% [markdown]
# Conclusion: Since the p value of 0.0005 is significantly less than 0.05, we have enough evidence to reject the null hypothesis. This suggests that 80 out of 124 couples tend to tilt their heads to the right when kissing, which is unlikely to happen randomly. Therefore, we conclude that people are more likely to tilt their heads to the right than to the left when kissing.

# %% [markdown]
# Q6. Can a smaller p-value definitively prove that the null hypothesis is false? Is it possible to definitively prove that Fido (from the "second pre-lecture video") is innocent using a p-value? Is it possible to difinitively prove that Fido is guilty using a p-value? How low or high does a p-value have to be to definitely prove one or the other? Explain this concisely in your own words.
#
# A p-value is a probability between 0 and 1, which is a range rather than an exact value. It helps to evaluate the consistency of observational data with the null hypothesis. A smaller p-value indicates stronger evidence against the null hypothesis, while a larger P-value indicates weaker evidence. However, the P-value does not provide absolute certainty because it only measures the probability of the data under the assumption that the null hypothesis is true. There are also two possible errors: Type 1 errors (false positives), where we reject the null hypothesis when it is actually true; Type 2 error (false negative), when the null hypothesis is false we cannot reject it. In Fido's case, the P-value can only indicate the strength of the evidence, and cannot definitively prove innocence or non-innocence, since it is never absolute evidence.

# %%
# Q7.In the second half of the "first pre-lecture video" the concept of a "one sided" (or "one tailed") test is introduced in contrast to a "two sided" (or "two tailed") test. Work with a ChatBot to adjust the code from "Demo II of the Week 5 TUT" (which revisits the "Vaccine Data Analysis Assignment" from Week 04 HW "Question 8") in order to compute a p-value for a "one sided" (or "one tailed") hypothesis test rather than the "two sided" (or "two tailed") version it provides. Describe (perhaps with the help of your ChatBot) what changed in the code; how this changes the interpretation of the hypothesis test; and whether or not we should indeed expect the p-value to be smaller in the "one tailed" versus "two tailed" analysis.

# %%
import numpy as np
import plotly.figure_factory as ff
import plotly.graph_objects as go
IncreaseProportionSimulations_underH0random = np.random.rand(100)  # Example random data
observed_statistic = 0.5  # Example observed statistic
population_parameter_value_under_H0 = 0.4  # Example population parameter

# Generate histogram data with slight random variation
hist_data = [IncreaseProportionSimulations_underH0random + np.random.uniform(-0.05, 0.05, size=len(IncreaseProportionSimulations_underH0random))]
group_labels = ['SYNTHETICALLY<br>SIMULATED<br>Sampling<br>Distribution<br>of the<br>Sample<br>Mean<br><br>assuming<br>that the<br>H0 null<br>hypothesis<br>IS TRUE']

# Create the distribution plot
fig = ff.create_distplot(hist_data, group_labels, curve_type='normal',
                         show_hist=True, show_rug=False, bin_size=0.1)

# Define p-value related variables
pv_y = 2.5
pv_y_ = 0.25

# Add the observed statistic line
fig.add_shape(type="line", x0=observed_statistic, y0=0, 
              x1=observed_statistic, y1=pv_y,
              line=dict(color="Green", width=4), name="Observed Statistic")

# Add observed statistic text
fig.add_trace(go.Scatter(x=[observed_statistic], y=[pv_y + pv_y_], 
                         text=["Observed<br>Statistic<br>^"], mode="text", showlegend=False))

# Adjust the upper extreme region only (single tail)
fig.add_shape(type="rect", x0=observed_statistic, y0=0, x1=1.25, y1=pv_y,
              fillcolor="LightCoral", opacity=0.5, line_width=0)

# Update layout
fig.update_layout(
    title="SYNTHETICALLY SIMULATED Sampling Distribution<br>under H0 with single-tailed p-value region",
    xaxis_title="Mean Health Score Change", 
    yaxis_title="Density", 
    yaxis=dict(range=[0, pv_y + 2 * pv_y_])
)

# Display the figure
fig.show(renderer="png")

# %% [markdown]
# Please provide a summary of our exchanges here so I can submit them as a record of our interactions as part of a homework assignment" ChatGPT said：You provided a summary of the modifications made to a code snippet for transitioning from a double-tailed to a single-tailed hypothesis test using Plotly for visualization. Key changes included removing the symmetric statistic calculations and lower tail shading, adjusting the upper tail shading to highlight the relevant area for the single-tailed test, and updating the plot title accordingly. Each modification was explained to clarify its impact on visualization and statistical interpretation. Additionally, you outlined methodologies for calculating p-values for both types of tests, shared sample Python code using the scipy.stats module, and discussed the interpretation of p-values, noting the differences in significance thresholds between single-tailed and double-tailed tests.
# https://chatgpt.com/share/67087f0f-29f8-8011-879e-f544bfd9e472

# %%
(1)
# Removed this code
symmetric_statistic = population_parameter_value_under_H0 -\
                           abs(observed_statistic-population_parameter_value_under_H0)
# In a double-tailed test, the symmetric statistic helps account for extreme values on both sides of the distribution. By removing this calculation, the focus shifts solely to the observed statistic in one direction (the right tail) for a single-tailed test. This simplifies the analysis and makes it relevant for testing against one hypothesis direction.

(2)
# Removed this shape
# fig.add_shape(type="rect", x0=-0.25, y0=0, x1=symmetric_statistic, y1=pv_y,
#               fillcolor="LightCoral", opacity=0.5, line_width=0)
# This rectangle was used to shade the lower tail of the distribution in a double-tailed test. Removing it ensures that only the upper tail, which is relevant for a single-tailed test, is shaded. This highlights the area of interest without cluttering the visualization.

(3)
# Adjusted to keep only the upper extreme region
fig.add_shape(type="rect", x0=observed_statistic, y0=0, x1=1.25, y1=pv_y,
              fillcolor="LightCoral", opacity=0.5, line_width=0)
# This code now adds a rectangle that shades the region above the observed statistic, indicating the area of interest for the single-tailed hypothesis test. It visually shows where extreme values lie in relation to the observed statistic, which is essential for interpreting the p-value.

(4)
# Removed these lines related to symmetric observed statistic
fig.add_shape(type="line", x0=symmetric_statistic, y0=0, 
              x1=symmetric_statistic, y1=pv_y,
              line=dict(color="Green", width=4), name="Observed Statistic")
fig.add_trace(go.Scatter(x=[symmetric_statistic], y=[pv_y+pv_y_], 
                         text=['"Symmetric" Observed Statistic<br>addrdssing for "as or more extreme"<br>^'], mode="text", showlegend=False))
# These lines were intended to visualize the symmetric observed statistic, which is not needed in a single-tailed test. Removing them reduces confusion and clarifies the plot by focusing on the relevant one-tailed analysis.

(5)
# Updated the title
fig.update_layout(
    title="SYNTHETICALLY SIMULATED Sampling Distribution<br>under H0 with single-tailed p-value region",
    ...
)
# The title change clarifies that the plot now represents a single-tailed hypothesis test. This helps viewers understand the context of the statistical analysis being performed, ensuring the focus is on the appropriate tail.
# Out:
#   Cell In[5], line 33
#     )
#     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# we should indeed expect the p-value to be smaller in the "one tailed" versus "two tailed" analysis.Because the probability of a two-tail test is the right-side probability plus the left-side symmetric point probability, it will be greater than the probability of a single-tail test that only looks at the right side.

# %% [markdown]
# Q8.Complete the following assignment.
# (1) In this experiment, our null hypothesis H0 is that the proportion of students correctly identifying the order of milk and tea pouring is equal to 0.5, which indicates that their judgment is merely the result of random guessing.In contrast, the alternative hypothesis Ha is that the students were able to correctly identify the pour order at a ratio of less than 0.5, meaning that their judgment ability exceeded the level of random guessing.

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

n = 80  
X = 49  
num_bootstrap_samples = 10000  
bootstrap_proportions = np.zeros(num_bootstrap_samples)

np.random.seed(42) 
for i in range(num_bootstrap_samples):
    sample = np.random.binomial(n, 0.5) 
    bootstrap_proportions[i] = sample / n 

observed_proportion = X / n
p_value = np.mean(bootstrap_proportions >= observed_proportion)

print("Observed Proportion:", observed_proportion)
print("Right-tailed p-value:", p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis, indicating that the sample proportion is significantly greater than 0.5.")
else:
    print("Fail to reject the null hypothesis, indicating that the sample proportion is not significantly greater than 0.5.")

plt.figure(figsize=(10, 6))
plt.hist(bootstrap_proportions, bins=30, alpha=0.7, color='blue', edgecolor='black', density=True)
plt.axvline(observed_proportion, color='red', linestyle='dashed', linewidth=2, 
            label=f'Observed Proportion ({observed_proportion:.2f})')
plt.title('Distribution of Simulated Proportions under Null Hypothesis')
plt.xlabel('Proportion of Correct Identifications')
plt.ylabel('Density')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# P-value = 0.0294:Since this P-value is less than the common significance level (e.g. 0.05), we can reject the null hypothesis H0.This showed that the ability of the 49 observed students to correctly identify the pouring order of milk and tea was significantly higher than the level of random guessing. That is, students' ability to judge is not random, but through recognition.
